# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjwalbhatnagar/Analysis-on-Weather-Data/blob/main/Data_Analysis_on_Weather_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6fcad0e-4007-4995-9052-0a45a8a8401d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6fcad0e-4007-4995-9052-0a45a8a8401d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WeatherData.csv to WeatherData.csv

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['WeatherData.csv']))

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# **.unique()**
#
# In a column, it shows all the unique values. It can be applied on a single column only, not on the whole dataframe.

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# **.nunique()**
#
# It shows the total no. of unique values in each column. It can be applied on a single column as well as on whole dataframe.

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# **.value_counts**
#
# In a column, it shows all the unique with their count. It can be applied on single column only.

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# **Q) Find all the unique 'wind speed' values in the data.**

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# **Q) Find the no. of times when the 'Weather is exactly Clear'.**

# %%
data[data.Weather == 'Clear'].value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/11/2012 1:00   -10.7   -17.8             56         17               25.0           101.49     Clear      1
# 6/14/2012 3:00    12.3    5.3              62         13               25.0           101.96     Clear      1
# 6/14/2012 23:00   19.6    5.8              40         6                25.0           102.21     Clear      1
# 6/14/2012 22:00   20.2    6.0              39         9                25.0           102.20     Clear      1
# 6/14/2012 21:00   21.0    6.0              38         11               25.0           102.16     Clear      1
#                                                                                                            ..
# 2/4/2012 19:00   -7.7    -14.0             61         7                25.0           101.97     Clear      1
# ...

# %%
data.groupby('Weather').get_group('Clear').count() #get_group gets a particular variable from row dataset.
# Out:
# Date/Time           1326
# Temp_C              1326
# Dew Point Temp_C    1326
# Rel Hum_%           1326
# Wind Speed_km/h     1326
# Visibility_km       1326
# Press_kPa           1326
# Weather             1326
# dtype: int64

# %% [markdown]
# **Q) Find the number of times when the 'Wind Speed was exactly 4 km/h.**

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# **Q) Find out all the Null Values in the data.**

# %%
data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# **Q) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.**

# %%
data.rename(columns = {'Weather Condition' : 'WC'}, inplace=True)

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa                    WC
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# **Q) What is the mean 'Visibility'?**

# %%
data['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# **Q) What is the Standard Deviation of 'Pressure' in data?**

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# **Q) What is the Variance of 'Realtive Humidity' in data?**

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# **Q) Find all instances when 'Snow' was recorded.**

# %%
data[data.WC == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa    WC
# ...

# %%
data[data['WC'].str.contains('Snow')].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WS  Visibility_km  \
# 41  1/2/2012 17:00    -2.1              -9.5         57  22           25.0
# 44  1/2/2012 20:00    -5.6             -13.4         54  24           25.0
# 45  1/2/2012 21:00    -5.8             -12.8         58  26           25.0
# 47  1/2/2012 23:00    -7.4             -14.1         59  17           19.3
# 48   1/3/2012 0:00    -9.0             -16.0         57  28           25.0
#
#     Press_kPa            WC
# 41      99.66  Snow Showers
# 44     100.07  Snow Showers
# 45     100.15  Snow Showers
# 47     100.27  Snow Showers
# 48     100.35  Snow Showers

# %% [markdown]
# **Q) Find all the instances when 'Wind Speed' is above 24' and 'Visibility is 25'.**

# %%
data.rename(columns ={'Wind Speed_km/h' : 'WS'}, inplace=True)

# %%
data[(data['WS'] > 24) & (data['Visibility_km'] ==25)].head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WS  Visibility_km  \
# 23  1/1/2012 23:00     5.3               2.0         79  30           25.0
# 24   1/2/2012 0:00     5.2               1.5         77  35           25.0
# 25   1/2/2012 1:00     4.6               0.0         72  39           25.0
# 26   1/2/2012 2:00     3.9              -0.9         71  32           25.0
# 27   1/2/2012 3:00     3.7              -1.5         69  33           25.0
#
#     Press_kPa             WC
# 23      99.31         Cloudy
# 24      99.26   Rain Showers
# 25      99.26         Cloudy
# 26      99.26  Mostly Cloudy
# 27      99.30  Mostly Cloudy

# %% [markdown]
# **Q) What is the mean value of each column against each 'Weather Condition'?**

# %%
data.groupby('WC').mean().head()
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%         WS  \
# WC
# Clear                    6.825716          0.089367  64.497738  10.557315
# Cloudy                   7.970544          2.375810  69.592593  16.127315
# Drizzle                  7.353659          5.504878  88.243902  16.097561
# Drizzle,Fog              8.067500          7.033750  93.275000  11.862500
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000  20.000000
#
#                          Visibility_km   Press_kPa
# WC
# Clear                        30.153243  101.587443
# Cloudy                       26.625752  100.911441
# Drizzle                      17.931707  100.435366
# Drizzle,Fog                   5.257500  100.786625
# Drizzle,Ice Pellets,Fog       4.000000  100.790000

# %% [markdown]
# Q)What is the Min and Max value of each column against each 'Weather Condition'?

# %%
data.groupby('WC').max()
y = data.groupby('WC').min()
res = (x,y)
res
# Out:
# (                                                Date/Time  Temp_C  \
#  WC
#  Clear                                       9/9/2012 5:00    32.8
#  Cloudy                                     9/9/2012 23:00    30.5
#  Drizzle                                    9/30/2012 3:00    18.8
#  Drizzle,Fog                                9/30/2012 2:00    19.9
#  Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
#  Drizzle,Snow                             12/19/2012 18:00     1.2
#  Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
#  Fog                                        9/22/2012 0:00    20.8
#  Freezing Drizzle                            2/1/2012 5:00    -2.3
#  Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
#  Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
#  Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
#  Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %% [markdown]
# **Q) Show all the records where weather condition is fog.**

# %%
data[data['WC'] == 'Fog'].head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  WS  Visibility_km  \
# 0  1/1/2012 0:00    -1.8              -3.9         86   4            8.0
# 1  1/1/2012 1:00    -1.8              -3.7         87   4            8.0
# 4  1/1/2012 4:00    -1.5              -3.3         88   7            4.8
# 5  1/1/2012 5:00    -1.4              -3.3         87   9            6.4
# 6  1/1/2012 6:00    -1.5              -3.1         89   7            6.4
#
#    Press_kPa   WC
# 0     101.24  Fog
# 1     101.24  Fog
# 4     101.23  Fog
# 5     101.27  Fog
# 6     101.29  Fog

# %% [markdown]
# **Q) Find all instances when 'Weather is Clear' or 'Visibility is above 40'?**

# %%
x = data[data['WC'] == 'Clear'] 
y = data[data['Visibility_km'] > 40]
res = pd.merge(x,y,on='Date/Time')
res.head()
# Out:
#          Date/Time  Temp_C_x  Dew Point Temp_C_x  Rel Hum_%_x  WS_x  \
# 0  1/15/2012 15:00     -15.4               -22.8           53    24
# 1  1/15/2012 16:00     -15.1               -22.8           52    24
# 2  1/18/2012 17:00     -11.3               -18.8           54    26
# 3   1/19/2012 8:00     -13.7               -18.4           68    19
# 4   1/19/2012 9:00     -12.7               -17.2           69    17
#
#    Visibility_km_x  Press_kPa_x   WC_x  Temp_C_y  Dew Point Temp_C_y  \
# 0             48.3       102.71  Clear     -15.4               -22.8
# 1             48.3       102.79  Clear     -15.1               -22.8
# 2             48.3       101.54  Clear     -11.3               -18.8
# 3             48.3       101.84  Clear     -13.7               -18.4
# 4             48.3       101.73  Clear     -12.7               -17.2
#
#    Rel Hum_%_y  WS_y  Visibility_km_y  Press_kPa_y   WC_y
# 0           53    24             48.3       102.71  Clear
# ...

# %% [markdown]
# **Q) Find all instances when 'weather is clear' and 'relative humidity is greater than 50' or 'visibility is above 40'?**

# %%
x = data[(data['WC'] == 'Clear') & (data['Rel Hum_%'] > 50)]
y = data[data['Visibility_km'] > 40]
res = pd.merge(x,y,on='Date/Time')
res.head()
# Out:
#          Date/Time  Temp_C_x  Dew Point Temp_C_x  Rel Hum_%_x  WS_x  \
# 0  1/15/2012 15:00     -15.4               -22.8           53    24
# 1  1/15/2012 16:00     -15.1               -22.8           52    24
# 2  1/18/2012 17:00     -11.3               -18.8           54    26
# 3   1/19/2012 8:00     -13.7               -18.4           68    19
# 4   1/19/2012 9:00     -12.7               -17.2           69    17
#
#    Visibility_km_x  Press_kPa_x   WC_x  Temp_C_y  Dew Point Temp_C_y  \
# 0             48.3       102.71  Clear     -15.4               -22.8
# 1             48.3       102.79  Clear     -15.1               -22.8
# 2             48.3       101.54  Clear     -11.3               -18.8
# 3             48.3       101.84  Clear     -13.7               -18.4
# 4             48.3       101.73  Clear     -12.7               -17.2
#
#    Rel Hum_%_y  WS_y  Visibility_km_y  Press_kPa_y   WC_y
# 0           53    24             48.3       102.71  Clear
# ...
